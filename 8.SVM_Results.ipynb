# %% [markdown]
# #### Outlier Removed
#
# array([[ 9,  5],
#        [ 2, 25]]
# Accuracy: 0.829
# Precision: 0.833
# Recall: 0.926
# F1 Score: 0.877
#
# #### Outlier Removed and Cross Validated
#
# accuracy =  0.853658536585366
# precision =  0.8955016835016835
# recall =  0.9019704433497535
# F1 score =  0.8969494889550681
# AUC ROC =  0.9212327901983075
#
# #### Outlier Removed and Balanced
#
# array([[ 8,  6],
#        [ 2, 25]]
# Accuracy: 0.805
# Precision: 0.806
# Recall: 0.926
# F1 Score: 0.862
#
# -----------------------------------------------------------
#
# #### Outlier Removed  and Scaled
#
# array([[ 8,  6],
#        [ 2, 25]]
# Accuracy: 0.805
# Precision: 0.806
# Recall: 0.926
# F1 Score: 0.862
#
# #### Outlier Removed and Cross Validated and Scaled
#
# accuracy =  0.8585365853658538
# precision =  0.9004259259259259
# recall =  0.9019704433497535
# F1 score =  0.8996993567498854
# AUC ROC =  0.9183844890741442
#
# #### Outlier Removed and Balanced and Scaled
#
# array([[ 8,  6],
#        [ 2, 25]]
# Accuracy: 0.805
# Precision: 0.806
# Recall: 0.926
# F1 Score: 0.862
#
# --------------------------------------

# %% [markdown]
# ## Results of Feature Selection, Outlier removed, scaled
#
# #### encoded_data[['ssc_p', 'degree_p', 'mba_p', 'hsc_p', 'workex', 'mba_t', 'degree_t', 'gender', 'etest_p', 'ssc_b', 'hsc_b', 'hsc_s']]
#
#     array([[ 8,  6],
#            [ 2, 25]]
#
#     Accuracy: 0.805
#     Precision: 0.806
#     Recall: 0.926
#     F1 Score: 0.862
#
# #### encoded_data[['ssc_p', 'degree_p', 'mba_p', 'hsc_p', 'workex', 'mba_t', 'degree_t', 'gender', 'ssc_b', 'hsc_b', 'hsc_s']]
#
#     array([[ 7,  7],
#            [ 2, 25]]
#
#     Accuracy: 0.780
#     Precision: 0.781
#     Recall: 0.926
#     F1 Score: 0.847
#
# #### **encoded_data[['ssc_p', 'degree_p', 'mba_p', 'hsc_p', 'workex', 'mba_t', 'degree_t', 'gender', 'etest_p']]**
#
#     array([[ 8,  6],
#            [ 2, 25]]
#
#     Accuracy: 0.805
#     Precision: 0.806
#     Recall: 0.926
#     F1 Score: 0.862
#
# #### encoded_data[['ssc_p', 'degree_p', 'mba_p', 'hsc_p', 'workex', 'mba_t', 'degree_t', 'gender']]
#
#     array([[ 7,  7],
#            [ 2, 25]]
#
#     Accuracy: 0.780
#     Precision: 0.781
#     Recall: 0.926
#     F1 Score: 0.847
#
# #### encoded_data[['ssc_p', 'degree_p', 'mba_p', 'workex', 'mba_t', 'degree_t', 'gender']]
#
#     array([[ 7,  7],
#            [ 2, 25]]
#
#     Accuracy: 0.780
#     Precision: 0.781
#     Recall: 0.926
#     F1 Score: 0.847
#
# #### encoded_data[['ssc_p', 'degree_p', 'mba_p', 'hsc_p', 'workex', 'mba_t', 'degree_t']]
#
#     array([[ 7,  7],
#            [ 2, 25]]
#
#     Accuracy: 0.780
#     Precision: 0.781
#     Recall: 0.926
#     F1 Score: 0.847
# #### encoded_data[['ssc_p', 'degree_p', 'mba_p', 'workex', 'mba_t', 'degree_t']]
#
#     array([[ 6,  8],
#            [ 2, 25]]
#
#     Accuracy: 0.756
#     Precision: 0.758
#     Recall: 0.926
#     F1 Score: 0.833
#
# > Selection of features here are reducing the performance of the model. So, we the bold result, where we eliminated which has  zero significance with status.

# %% [markdown]
# #### Feature Scaled, Outlier Removed, Balanced, Feature Selected
# array([[ 7,  7],
#        [ 2, 25]]
#
# Accuracy: 0.780
# Precision: 0.781
# Recall: 0.926
# F1 Score: 0.847

# %% [markdown]
# > Many alternative tries like hyper parameter tuning etc... also resulted in vain.
# Out of all, the base model is the best result.
